# %% [markdown]
# ## Glassdoor Jobs Dataset

# %% [markdown]
# Glassdoor Jobs Data that having many issues, through differant data wrangling task we going to clean.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings ('ignore')

# %% [markdown]
# #### Load Data

# %%
# Load data
df = pd.read_csv('v1.2.csv')

# %%
df.head()
# Out:
#                                 Unnamed: 0                Unnamed: 1  \
# 0                                      NaN                       NaN
# 1                                      NaN                       NaN
# 2                              Competitors                   Revenue
# 3  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 4                                       -1    $1 to $2 billion (USD)
#
#       GLASSDOOR JOBS              Unnamed: 3              Unnamed: 4  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2             Sector                Industry          Ownership Type
# 3          Insurance      Insurance Carriers  Nonprofit Organization
# 4  Business Services  Research & Development        Company - Public
#
#   Unnamed: 5               Unnamed: 6    Unnamed: 7     Unnamed: 8  \
# ...

# %%
df = pd.read_csv ('v1.2.csv', skiprows= 3)
df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
df.drop ('index', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
# df Columns
df.columns
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating',
#        'Description', 'Salary', 'Title'],
#       dtype='object')

# %%
# Stoaring to list
cols = df.columns
cols
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating',
#        'Description', 'Salary', 'Title'],
#       dtype='object')

# %%
# columns 0:11 with related to Company
cols[0:11] # Company
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating'],
#       dtype='object')

# %%
# columns 11:14 with related to Job Cols
cols[11:14] # Job Cols
# Out:
# Index(['Description', 'Salary', 'Title'], dtype='object')

# %%
# adding 'C_' 
l1 = 'C_'+ cols[0:11]
l1
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating'],
#       dtype='object')

# %%
# adding 'J_'
l2 = 'J_'+ cols[11:14]
l2
# Out:
# Index(['J_Description', 'J_Salary', 'J_Title'], dtype='object')

# %%
# Apped to lists
newlist = l1.append(l2)
newlist
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
# new names to columns
df.columns = newlist

# %%
# Check df
df.head()
# Out:
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                     C_Revenue           C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                               C_Industry         C_Ownership Type  C_Founded  \
# 0                     Insurance Carriers   Nonprofit Organization       1993
# 1                 Research & Development         Company - Public       1968
# 2                             Consulting  Private Practice / Firm       1981
# ...

# %%
# Copping Data
df2 = df.copy()

# %% [markdown]
# #### Above operation can be done using add_prefix, add_suffix

# %%
# Adding prefix

df2.add_prefix('Glassdoor_').head()
# Out:
#                              Glassdoor_C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#           Glassdoor_C_Revenue Glassdoor_C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                     Glassdoor_C_Industry Glassdoor_C_Ownership Type  \
# 0                     Insurance Carriers     Nonprofit Organization
# 1                 Research & Development           Company - Public
# 2                             Consulting    Private Practice / Firm
# 3  Electrical & Electronic Manufacturing           Company - Public
# ...

# %% [markdown]
# #### Reordering the Columns

# %%
# 'J_' at front and '_C' at end
# checking df
df.head(2)
# Out:
#                              C_Competitors                 C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#             C_Sector              C_Industry        C_Ownership Type  \
# 0          Insurance      Insurance Carriers  Nonprofit Organization
# 1  Business Services  Research & Development        Company - Public
#
#    C_Founded                   C_Size C_Headquarters     C_Location  \
# 0       1993   1001 to 5000 employees   New York, NY   New York, NY
# 1       1968  5001 to 10000 employees    Herndon, VA  Chantilly, VA
#
#              C_Name C_Rating  \
# 0  Healthfirst\n3.1      3.1
# 1      ManTech\n4.2      4.2
#
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
#
#                        J_Salary            J_Title
# ...

# %%
# Method 1
df3 = df[['J_Description', 'J_Salary','J_Title','C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
       'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
       'C_Location', 'C_Name', 'C_Rating']]
df3.head(2)
# Out:
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
#
#                        J_Salary            J_Title  \
# 0  $137K-$171K (Glassdoor est.)  Sr Data Scientist
# 1  $137K-$171K (Glassdoor est.)     Data Scientist
#
#                              C_Competitors                 C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#             C_Sector              C_Industry        C_Ownership Type  \
# 0          Insurance      Insurance Carriers  Nonprofit Organization
# 1  Business Services  Research & Development        Company - Public
#
#    C_Founded                   C_Size C_Headquarters     C_Location  \
# 0       1993   1001 to 5000 employees   New York, NY   New York, NY
# 1       1968  5001 to 10000 employees    Herndon, VA  Chantilly, VA
#
# ...

# %%
# Method- 2

df [list(df.columns[11:14]) + list(df.columns[0:11]) ].head(2)
# Out:
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
#
#                        J_Salary            J_Title  \
# 0  $137K-$171K (Glassdoor est.)  Sr Data Scientist
# 1  $137K-$171K (Glassdoor est.)     Data Scientist
#
#                              C_Competitors                 C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#             C_Sector              C_Industry        C_Ownership Type  \
# 0          Insurance      Insurance Carriers  Nonprofit Organization
# 1  Business Services  Research & Development        Company - Public
#
#    C_Founded                   C_Size C_Headquarters     C_Location  \
# 0       1993   1001 to 5000 employees   New York, NY   New York, NY
# 1       1968  5001 to 10000 employees    Herndon, VA  Chantilly, VA
#
# ...

# %%
# Method- 3 (More faster way)

df.head(2)
# Out:
#                              C_Competitors                 C_Revenue  \
# 0  EmblemHealth, UnitedHealth Group, Aetna  Unknown / Non-Applicable
# 1                                       -1    $1 to $2 billion (USD)
#
#             C_Sector              C_Industry        C_Ownership Type  \
# 0          Insurance      Insurance Carriers  Nonprofit Organization
# 1  Business Services  Research & Development        Company - Public
#
#    C_Founded                   C_Size C_Headquarters     C_Location  \
# 0       1993   1001 to 5000 employees   New York, NY   New York, NY
# 1       1968  5001 to 10000 employees    Herndon, VA  Chantilly, VA
#
#              C_Name C_Rating  \
# 0  Healthfirst\n3.1      3.1
# 1      ManTech\n4.2      4.2
#
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
#
#                        J_Salary            J_Title
# ...

# %%
# revesing using loc[]
df = df.loc[:,::-1]
df.columns
# Out:
# Index(['J_Title', 'J_Salary', 'J_Description', 'C_Rating', 'C_Name',
#        'C_Location', 'C_Headquarters', 'C_Size', 'C_Founded',
#        'C_Ownership Type', 'C_Industry', 'C_Sector', 'C_Revenue',
#        'C_Competitors'],
#       dtype='object')

# %%
df.head(2)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...      3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...      4.2
#
#              C_Name     C_Location C_Headquarters                   C_Size  \
# 0  Healthfirst\n3.1   New York, NY   New York, NY   1001 to 5000 employees
# 1      ManTech\n4.2  Chantilly, VA    Herndon, VA  5001 to 10000 employees
#
#    C_Founded        C_Ownership Type              C_Industry  \
# 0       1993  Nonprofit Organization      Insurance Carriers
# 1       1968        Company - Public  Research & Development
#
#             C_Sector                 C_Revenue  \
# 0          Insurance  Unknown / Non-Applicable
# 1  Business Services    $1 to $2 billion (USD)
#
#                              C_Competitors
# ...

# %%
# data type of columns for 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           684 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Description     689 non-null    object
#  3   C_Rating          684 non-null    object
#  4   C_Name            689 non-null    object
#  5   C_Location        689 non-null    object
#  6   C_Headquarters    689 non-null    object
#  7   C_Size            689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Ownership Type  689 non-null    object
#  10  C_Industry        689 non-null    object
#  11  C_Sector          689 non-null    object
#  12  C_Revenue         689 non-null    object
#  13  C_Competitors     689 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 75.5+ KB

# %% [markdown]
# #### Cleaninig dataset >> checking nulls

# %%
# Checking null

df.isna().sum()
# Out:
# J_Title             5
# J_Salary            0
# J_Description       0
# C_Rating            5
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# dtype: int64

# %%
# C_Rating is in object type, it should be numeric

# %%
df[df.C_Rating.isna()]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      NaN
# 67   As a member of the Data Science team, this rol...      NaN
# 157  *******Please Apply using this link: https://a...      NaN
# 350  What will you be doing?\n\nThe Contractor shal...      NaN
# 686  As a member of the Data Science team, this rol...      NaN
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %%
# Not Null
df[~df.C_Rating.isna()]
# Out:
#                                J_Title                      J_Salary  \
# 0                    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                       Data Scientist  $137K-$171K (Glassdoor est.)
# 2                       Data Scientist  $137K-$171K (Glassdoor est.)
# 3                       Data Scientist  $137K-$171K (Glassdoor est.)
# 4                                  NaN  $137K-$171K (Glassdoor est.)
# ..                                 ...                           ...
# 683                Global Data Analyst   $79K-$131K (Glassdoor est.)
# 684                      Data Engineer   $79K-$131K (Glassdoor est.)
# 685                     Data Scientist   $79K-$131K (Glassdoor est.)
# 687  Data & Machine Learning Scientist   $79K-$131K (Glassdoor est.)
# 688  Data Scientist - Machine Learning   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...      3.1
# ...

# %%
# Problematic values

for i in (df[~df.C_Rating.isna()]['C_Rating']):
    if len(i)>3:
        print (i)
# Out:
# 4.4*
# /3.7
# 3.8*/
# 2*+.9

# %%
l=[]
for i in (df['C_Rating']):
    try:
        pd.to_numeric(i)
    except ValueError:
        l.append(i)
print('Enormous Case:', l)
# Out:
# Enormous Case: ['4.4*', '/3.7', '3.8*/', '2*+.9']

# %%
# null index of above values

idx = df[df['C_Rating'].isna()].index
idx
# Out:
# Index([49, 67, 157, 350, 686], dtype='int64')

# %%
# Replacing null

lis = []

for i in range(0,len(idx)):
    lis.append(df.iloc[idx[i]]['C_Name'].split('\n')[1])

# %%
lis
# Out:
# ['4.3', '4.0', '4.4', '4.7', '4.0']

# %%
# Replacing values to respective location 
df.iloc[idx,3]=lis

# %%
# checking Replacing values to respective location
df.iloc[idx]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      4.3
# 67   As a member of the Data Science team, this rol...      4.0
# 157  *******Please Apply using this link: https://a...      4.4
# 350  What will you be doing?\n\nThe Contractor shal...      4.7
# 686  As a member of the Data Science team, this rol...      4.0
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %%
df.C_Rating.isna().sum()
# Out:
# 0

# %%
# Making function

def cleaner(str):
    cleaner_str  = ''.join(filter(lambda x: x in ('0123456789.'),str))
    return float(cleaner_str)

# %%
#applying function
df['C_Rating']= df['C_Rating'].apply(cleaner)

# %%
# Checking Shape
df['C_Rating'].dtype
# Out:
# dtype('float64')

# %%
# checking column

df.C_Rating.describe()
# Out:
# count    689.000000
# mean       3.672859
# std        0.953591
# min        1.000000
# 25%        3.400000
# 50%        3.800000
# 75%        4.300000
# max        5.600000
# Name: C_Rating, dtype: float64

# %%
# Now task is to clean >>> Clean >>> C_Name

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           684 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Description     689 non-null    object
#  3   C_Rating          689 non-null    float64
#  4   C_Name            689 non-null    object
#  5   C_Location        689 non-null    object
#  6   C_Headquarters    689 non-null    object
#  7   C_Size            689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Ownership Type  689 non-null    object
#  10  C_Industry        689 non-null    object
#  11  C_Sector          689 non-null    object
#  12  C_Revenue         689 non-null    object
#  13  C_Competitors     689 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 75.5+ KB

# %%
df.head()
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                NaN  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...       3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...       2.9
#
#                     C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
name1 = df['C_Name'].str.split('\n')
name1
# Out:
# 0                   [Healthfirst, 3.1]
# 1                       [ManTech, 4.2]
# 2                [Analysis Group, 3.8]
# 3                       [INFICON, 3.5]
# 4            [Affinity Solutions, 2.9]
#                     ...
# 684    [Bayview Asset Management, 3.7]
# 685          [Via Transportation, 3.7]
# 686               [Grid Dynamics, 4.0]
# 687                 [Tempus Labs, 3.3]
# 688                      [CareDx, 2.5]
# Name: C_Name, Length: 689, dtype: object

# %%
list2 = []

for i in name1:
    list2.append(i[0])
# print(list2)

# %%
#  New column > cleaned
df['C_Name1'] = list2
df.head(2)
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
#
#              C_Name     C_Location C_Headquarters                   C_Size  \
# 0  Healthfirst\n3.1   New York, NY   New York, NY   1001 to 5000 employees
# 1      ManTech\n4.2  Chantilly, VA    Herndon, VA  5001 to 10000 employees
#
#    C_Founded        C_Ownership Type              C_Industry  \
# 0       1993  Nonprofit Organization      Insurance Carriers
# 1       1968        Company - Public  Research & Development
#
#             C_Sector                 C_Revenue  \
# 0          Insurance  Unknown / Non-Applicable
# 1  Business Services    $1 to $2 billion (USD)
#
# ...

# %%
# IN some column -1 value

# %%
df.eq(-1).sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters        0
# C_Size                0
# C_Founded           119
# C_Ownership Type      0
# C_Industry            0
# C_Sector              0
# C_Revenue             0
# C_Competitors         0
# C_Name1               0
# dtype: int64

# %%
# Total -1 values
(df.eq(-1)+df.eq('-1')).sum()
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# C_Name1               0
# dtype: int64

# %%
# Column list
cols = df.columns
cols
# Out:
# Index(['J_Title', 'J_Salary', 'J_Description', 'C_Rating', 'C_Name',
#        'C_Location', 'C_Headquarters', 'C_Size', 'C_Founded',
#        'C_Ownership Type', 'C_Industry', 'C_Sector', 'C_Revenue',
#        'C_Competitors', 'C_Name1'],
#       dtype='object')

# %%
# replacing to Nan
for i in cols:
    df.loc[df[i].isin([-1,'-1']),i] = np.NaN

# %%
df.isna().sum()
# Out:
# J_Title               5
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# C_Name1               0
# dtype: int64

# %%
# shape
df.shape
# Out:
# (689, 15)

# %%
# droping nan
df.dropna(axis=0, inplace=True)

# %%
# after drpping df shape
df.shape
# Out:
# (170, 15)

# %%
df.isna().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_Name1             0
# dtype: int64

# %%
# df
df.head()
# Out:
#                              J_Title                      J_Salary  \
# 0                  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 3                     Data Scientist  $137K-$171K (Glassdoor est.)
# 8   Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 10                    Data Scientist  $137K-$171K (Glassdoor est.)
# 11                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                         J_Description  C_Rating  \
# 0   Description\n\nThe Senior Data Scientist is re...       3.1
# 3   JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 8   Intuit is seeking a Staff Data Scientist to co...       4.4
# 10  Join our team dedicated to developing and exec...       4.5
# 11  About Us\n\n\nInterested in working for a huma...       4.7
#
#                 C_Name       C_Location          C_Headquarters  \
# 0     Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
# Index not proper
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
# Creating new df
df4 = df.copy()

# %%
df['C_City']= df['C_Location'].apply(lambda x: x.split(',')[0])

# %%
df.head(3)
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
#
#                C_Name     C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1   New York, NY            New York, NY
# 1        INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 2  Intuit - Data\n4.4  San Diego, CA       Mountain View, CA
#
#                     C_Size  C_Founded        C_Ownership Type  \
# 0   1001 to 5000 employees     1993.0  Nonprofit Organization
# 1    501 to 1000 employees     2000.0        Company - Public
# ...

# %%
loc= list(df.C_Location.unique())
print(loc)
# Out:
# ['New York, NY', 'Newton, MA', 'San Diego, CA', 'Herndon, VA', 'Saint Louis, MO', 'Richland, WA', 'Plano, TX', 'Appleton, WI', 'United States', 'Overland Park, KS', 'Santa Monica, CA', 'Portsmouth, NH', 'Cambridge, MA', 'San Francisco, CA', 'Fort Wayne, IN', 'Carson, CA', 'Santa Clara, CA', 'Winter Park, FL', 'Peoria, IL', 'Ipswich, MA', 'Carmel, IN', 'Washington, DC', 'Gaithersburg, MD', 'Denver, CO', 'Chantilly, VA', 'Reston, VA', 'Bethesda, MD', 'Dayton, OH', 'McLean, VA', 'Woodbridge, NJ', 'Vicksburg, MS', 'Blue Bell, PA', 'Chicago, IL', 'Redwood City, CA', 'San Carlos, CA', 'Waltham, MA', 'Fort Worth, TX', 'Fort Belvoir, VA', 'Oklahoma City, OK', 'Champaign, IL', 'Texas', 'Lebanon, IN', 'Melbourne, FL', 'Cleveland, OH', 'San Jose, CA', 'Danvers, MA', 'Livermore, CA', 'Northbrook, IL', 'Oshkosh, WI', 'Ann Arbor, MI', 'Richmond, VA', 'Boston, MA', 'Kent, OH', 'Laurel, MD', 'Fremont, CA', 'Indianapolis, IN', 'Oxnard, CA', 'Kansas City, MO', 'Manchester, NH', 'Atlanta, GA', 'Falls C
# ...

# %%
for i in loc:
    if "," not in i:
        print(i)
# Out:
# United States
# Texas

# %%
df[df['C_Location'].isin(['United States', 'Texas'])]
# Out:
#             J_Title                      J_Salary  \
# 9     Data Engineer   $75K-$131K (Glassdoor est.)
# 70   Data Scientist   $71K-$123K (Glassdoor est.)
# 131  Data Scientist  $212K-$331K (Glassdoor est.)
# 154  Data Scientist   $87K-$141K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 9    Chef Software is the industry leader in IT aut...       3.6
# 70   Who we are\n\n\nFueled by a fundamental belief...       3.8
# 131  Position: Data Scientist\nLocation: Denver\nSt...       3.6
# 154  Business Unit:\nCubic Transportation Systems\n...       3.3
#
#                    C_Name     C_Location   C_Headquarters  \
# 9               Chef\n3.6  United States      Seattle, WA
# 70            PayPal\n3.8          Texas     San Jose, CA
# 131  Creative Circle\n3.6  United States  Los Angeles, CA
# 154            Cubic\n3.3  United States    San Diego, CA
#
#                       C_Size  C_Founded   C_Ownership Type  \
# ...

# %%
df2 = df[~(df['C_Location']== 'United States')].reset_index(drop=True)
df2
# Out:
#                                        J_Title                      J_Salary  \
# 0                            Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                               Data Scientist  $137K-$171K (Glassdoor est.)
# 2             Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                               Data Scientist  $137K-$171K (Glassdoor est.)
# 4                               Data Scientist  $137K-$171K (Glassdoor est.)
# ..                                         ...                           ...
# 162  Product Data Scientist - Ads Data Science   $75K-$131K (Glassdoor est.)
# 163                             Data Scientist   $75K-$131K (Glassdoor est.)
# 164                               Data Analyst   $75K-$131K (Glassdoor est.)
# 165                        Global Data Analyst   $79K-$131K (Glassdoor est.)
# 166                             Data Scientist   $79K-$131K (Glassdoor est.)
#
# ...

# %%
df2['C_State']= df2[df2['C_Location'] != 'Texas']['C_Location'].apply(lambda x: x.split(',')[1])

# %%
df2.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
df2.isna().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_Name1             0
# C_City              0
# C_State             1
# dtype: int64

# %%
# Texas remain to fill
df2['C_State'].fillna('TX', inplace=True)
df2.isna().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_Name1             0
# C_City              0
# C_State             0
# dtype: int64

# %%
df2 = df2.sort_values('C_State')
df2.head()
# Out:
#                                             J_Title  \
# 166                                  Data Scientist
# 28   Data Science Manager, Payment Acceptance - USA
# 30                 Staff Data Scientist - Analytics
# 33                             Staff Data Scientist
# 119                Data Analyst - Unilever Prestige
#
#                         J_Salary  \
# 166  $79K-$131K (Glassdoor est.)
# 28   $79K-$131K (Glassdoor est.)
# 30   $99K-$132K (Glassdoor est.)
# 33   $99K-$132K (Glassdoor est.)
# 119  $69K-$116K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 166  As a member of the Data Science team, this rol...       4.0
# 28   Build out rigorous observability and optimizat...       4.0
# 30   Intuit is seeking a Staff Data Scientist to co...       4.4
# 33   Intuit is hiring a Senior Data scientist to fo...       4.4
# 119  Data Analyst - Unilever Prestige\nJob Code\n\n...       3.8
#
# ...

# %%
df2.set_index(['C_State', 'C_City'], drop=False, inplace=True)

# %%
df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)
#         San Francisco  $79K-$131K (Glassdoor est.)
#         San Diego      $99K-$132K (Glassdoor est.)
#         San Diego      $99K-$132K (Glassdoor est.)
#         Carson         $69K-$116K (Glassdoor est.)
#
#                                                            J_Description  \
# C_State C_City
#  CA     Santa Clara    As a member of the Data Science team, this rol...
# ...

# %%
## Salary Column

# %%
import regex as re

# %%
re.sub('[^0-9−]', '','69𝐾−116K (Glassdoor est.)')
# Out:
# '69−116'

# %%
# https://learn.upgrad.com/course/5701/segment/57305/350024/1056406/5279037

# %%
df2['Salary_Estimate'] = df2['J_Salary'].apply(lambda x: re.sub('[^0-9-]', '', x))

# %%
df2.head(2)
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#
#                                           J_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)
#         San Francisco  $79K-$131K (Glassdoor est.)
#
#                                                            J_Description  \
# C_State C_City
#  CA     Santa Clara    As a member of the Data Science team, this rol...
#         San Francisco  Build out rigorous observability and optimizat...
#
#                        C_Rating              C_Name         C_Location  \
# C_State C_City
#  CA     Santa Clara         4.0  Grid Dynamics\n4.0    Santa Clara, CA
#         San Francisco       4.0         Stripe\n4.0  San Francisco, CA
#
#                           C_Headquarters                  C_Size  C_Founded  \
# ...

# %%
# df2['Min_Salary'] = df2['Salary_Estimate'].apply(lambda x: float(x.split('-')[0]))

# %%
df2.insert(2, 'Min_Salary', df2['Salary_Estimate'].apply(lambda x: float(x.split('-')[0])))

# %%
df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0
#
#                                                            J_Description  \
# C_State C_City
# ...

# %%
df2.insert(3, 'Max_Salary', df2['Salary_Estimate'].apply(lambda x: float(x.split('-')[1])))

# %%
df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 167 entries, (' CA', 'Santa Clara') to ('TX', 'Texas')
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           167 non-null    object
#  1   J_Salary          167 non-null    object
#  2   Min_Salary        167 non-null    float64
#  3   Max_Salary        167 non-null    float64
#  4   J_Description     167 non-null    object
#  5   C_Rating          167 non-null    float64
#  6   C_Name            167 non-null    object
#  7   C_Location        167 non-null    object
#  8   C_Headquarters    167 non-null    object
#  9   C_Size            167 non-null    object
#  10  C_Founded         167 non-null    float64
#  11  C_Ownership Type  167 non-null    object
#  12  C_Industry        167 non-null    object
#  13  C_Sector          167 non-null    object
#  14  C_Revenue         167 non-null    object
# ...

# %%
df2[['Min_Salary','Max_Salary']].describe()
# Out:
#        Min_Salary  Max_Salary
# count  167.000000  167.000000
# mean    97.467066  145.862275
# std     32.720942   46.655094
# min     31.000000   56.000000
# 25%     79.000000  123.000000
# 50%     91.000000  132.000000
# 75%    112.000000  163.000000
# max    212.000000  331.000000

# %% [markdown]
# #### Bining

# %%
df3 = df2.copy()

# %%
df3['Min_Sal_Range'] = pd.cut(df2['Min_Salary'], bins=[56,100,160,330], labels=['L','M', 'H'])

# %%
df3.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
df3.Min_Sal_Range.value_counts()
# Out:
# Min_Sal_Range
# L    95
# M    54
# H     5
# Name: count, dtype: int64

# %%
# but above is not right way , here using qcut
df3.drop ('Min_Sal_Range', axis=1, inplace=True)

# %%
df3['Min_Sal_Range'] = pd.qcut(df3['Min_Salary'], q=3, labels=['L', 'M', 'H'])

# %%
df3['Max_Sal_Range'] = pd.qcut(df3['Max_Salary'], q=3, labels=['L', 'M', 'H'])

# %%
df3.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
df3.Max_Sal_Range.value_counts()
# Out:
# Max_Sal_Range
# L    79
# H    56
# M    32
# Name: count, dtype: int64
